# %%
import sys
import time
import h5py
import torch
import math
from torch import nn, optim
from torch.utils.data import DataLoader, TensorDataset
from utils import show_graph_loss, log_accuracy

# %% [markdown]
# # Data loading

# %%
# Connect torch to GPU
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

print(device)
# Out:
# cuda

# %%
# Load test set
f = h5py.File('../data/experiment/sdr_wifi_test.hdf5', 'r')
X_test = f['X'][()]
y_test = f['y'][()]
f.close()

# Load train set
f = h5py.File('../data/experiment/sdr_wifi_train.hdf5', 'r')
X_train = f['X'][()]
y_train = f['y'][()]
f.close()

# %% [markdown]
# # Description of input variables
#
# - `sequence_length` is the amount of IQ samples is in a single sample of data
# - `nm_channels` is the amount of number each IQ samples consists of (2)
# - `num_layers` is the amount of hidden layers that perform changes to get the correct prediction (chosen based on https://stats.stackexchange.com/questions/181/how-to-choose-the-number-of-hidden-layers-and-nodes-in-a-feedforward-neural-netw)
# - `output_size` is the amount of frequencies that are predicted, these are equal to the input since we want to see from the full prediction which frequency most likely has the lowest interference
# - `num_epochs` is the amount of training rounds
# - `learning_rate` is the rate at which the weights of the hidden layers are updated to improve prediction results (cannot be too high because it might overshoot)

# %%
data = torch.FloatTensor(X_train).to(device)
labels = torch.FloatTensor(y_train).to(device)

print(data.shape)
print(labels.shape)

# Neural network input
sequence_length = data.shape[1]
num_channels = data.shape[2]
num_layers = 1
output_size = labels.shape[1]

learning_rate = 1e-3
num_epochs = 20
batch_size = 128
# Out:
# torch.Size([629987, 64, 2])
# torch.Size([629987, 4])

# %% [markdown]
# # Model definition

# %%
USE_LOGITS = True

# %%
class ConvSVMModel(nn.Module):
    def __init__(self, sequence_length, num_channels = 2, output_size = 4):
        super(ConvSVMModel, self).__init__()
        # Convolutional layers to extract more features from IQ samples improving classification
        self.conv1 = nn.Conv1d(in_channels=num_channels, out_channels=16, kernel_size=3, stride=1, padding=1)
        self.conv2 = nn.Conv1d(in_channels=16, out_channels=32, kernel_size=3, stride=1, padding=1)

        # Fully connected layers to classify the signal with it's features extracted by the convolutional layers
        self.fc1 = nn.Linear(32 * sequence_length, 128)
        self.fc2 = nn.Linear(128, output_size)

    def forward(self, x):
        # Step 1: get more information out of the IQ samples using convolution
        # Input shape: [batch_size, sequence_length, 2]
        x = x.permute(0, 2, 1)  # -> [batch_size, 2, sequence_length]

        # First convolutional layer
        x = self.conv1(x) # -> [batch_size, 16, sequence_length]
        x = torch.relu(x) # -> [batch_size, 16, sequence_length]

        # Second convolutional layer
        x = self.conv2(x) # -> [batch_size, 32, sequence_length]
        x = torch.relu(x) # -> [batch_size, 32, sequence_length]

        # Step 2: flatten the output of the convolutional layers
        x = x.view(x.size(0), -1)  # -> [batch_size, 32 * sequence_length]

        # Step 3: use a fully connected layer to classify the signal
        x = self.fc1(x) # -> [batch_size, 128]
        x = torch.relu(x) # -> [batch_size, 128]
        x = self.fc2(x) # -> [batch_size, output_size]

        if not USE_LOGITS:
            x = torch.sigmoid(x)
        
        return x

# Initialize the model, loss function, and optimizer
model = ConvSVMModel(
    sequence_length=sequence_length,
    num_channels=num_channels,
    output_size=output_size
).to(device)
criterion = nn.BCEWithLogitsLoss() if USE_LOGITS else nn.BCELoss()
optimizer = optim.Adam(model.parameters(), lr=learning_rate)
scheduler = optim.lr_scheduler.StepLR(optimizer, step_size=10, gamma=0.1)

# %% [markdown]
# # Training

# %%
dataset = TensorDataset(data, labels)
train_loader = DataLoader(dataset, batch_size=batch_size, shuffle=True)

avg_loss_history = []
avg_loss = 0

min_loss_history = []
max_loss_history = []

start_time = time.time()

# Training loop
for epoch in range(num_epochs):
    model.train()
    total_loss = 0
    min_loss = 10
    max_loss = 0

    for i, (x_batch, y_batch) in enumerate(train_loader):
        # Forward pass
        outputs = model(x_batch)
        loss = criterion(outputs, y_batch)
        
        # Backward pass and optimization
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        current_loss = loss.item()
        total_loss += current_loss
        min_loss = min(min_loss, current_loss)
        max_loss = max(max_loss, current_loss)

        sys.stdout.write(f"\rEpoch [{epoch + 1}/{num_epochs}] | ({i} / {math.floor(len(data) / batch_size)}) | Loss: {loss.item():.4f} | Avg Loss last epoch: {avg_loss:.4f}")

    avg_loss = total_loss / len(train_loader)
    avg_loss_history.append(avg_loss)
    min_loss_history.append(min_loss)
    max_loss_history.append(max_loss)

    # Step the scheduler
    scheduler.step()

end_time = time.time()

training_time = end_time - start_time
# Out:
# Epoch [20/20] | (4921 / 4921) | Loss: 0.0008 | Avg Loss last epoch: 0.0018

# %% [markdown]
# # Testing

# %%
model.eval()
with torch.no_grad():
    total_loss = 0
    correct_predictions = 0
    total_samples = 0

    for i in range(0, len(X_test), batch_size):
        X_batch = torch.FloatTensor(X_test[i:i+batch_size]).to(device)
        y_batch = torch.FloatTensor(y_test[i:i+batch_size]).to(device)

        outputs = model(X_batch)
        loss = criterion(outputs, y_batch)

        total_loss += loss.item()

        # Convert probabilities to binary predictions
        predicted = (outputs > 0).float()

        # Calculate the number of correct predictions
        correct_predictions += (predicted == y_batch).sum().item()
        total_samples += y_batch.numel()

        sys.stdout.write(f"\rTest Loss: {loss.item():.4f}")

    accuracy = correct_predictions / total_samples
    print(f"\nTotal Test Loss: {total_loss}")
    print(f"Test Accuracy: {accuracy:.4f}")

print("\nDone!")
# Out:
# Test Loss: 0.0004
# Total Test Loss: 1.0056751985715888
# Test Accuracy: 0.9993
#
# Done!

# %% [markdown]
# # Documentation

# %%
import time
import pandas as pd

# Make a prediction based on the last sample
model.eval()

results = []

with torch.no_grad():
    for i in range(100):
        X_sample = torch.FloatTensor(X_test[i]).to(device)
        
        # Change shape from (256, 2) to (1, 256, 2)
        X_sample = X_sample.unsqueeze(0)

        time_start = time.time()

        output = model(X_sample)

        time_end = time.time()

        predicted = (output > 0).float()
        results.append({
            'index': i,
            'predicted': predicted.tolist()[0],
            'actual': y_test[i].tolist(),
            'output': output,
            'time': (time_end - time_start) * 1000,
            'total_accuracy': accuracy
        })

results_df = pd.DataFrame(results)
results_df.to_csv('../docs/results/conv_svm/conv_svm_tests.csv', index=False)

# %%
log_accuracy(
    model='conv_svm',
    label='Convolutional SVM model (recorded data)',
    data=data,
    accuracy=accuracy,
    training_time=training_time,
    num_epochs=num_epochs,
    avg_response_time=results_df['time'].mean(),
    avg_loss=avg_loss,
    min_loss=min_loss,
    max_loss=max_loss,
    sampling_rate=1
)

# %%
show_graph_loss(
    plot_label="Convolutional SVM", 
    loss_history=avg_loss_history, 
    num_epochs=num_epochs, 
    label='avg', 
    filename='../docs/results/conv_svm/conv_svm_avg_loss.png'
)
show_graph_loss(
    plot_label="Convolutional SVM", 
    loss_history=min_loss_history, 
    num_epochs=num_epochs, 
    label='min', 
    filename='../docs/results/conv_svm/conv_svm_min_loss.png'
)
show_graph_loss(
    plot_label="Convolutional SVM", 
    loss_history=max_loss_history, 
    num_epochs=num_epochs, 
    label='max', 
    filename='../docs/results/conv_svm/conv_svm_max_loss.png'
)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\torch\onnx\_internal\onnx_proto_utils.py:220, in _add_onnxscript_fn(model_bytes, custom_opsets)
#     219 try:
# --> 220     import onnx
#     221 except ImportError as e:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\onnx\__init__.py:118
#     117 # Import common subpackages so they're available when you 'import onnx'
# --> 118 from onnx import (
#     119     checker,
#     120     compose,
#     121     defs,
#     122     gen_proto,
#     123     helper,
#     124     hub,
#     125     mapping,
#     126     numpy_helper,
#     127     parser,
#     128     printer,
#     129     shape_inference,
#     130     utils,
#     131     version_converter,
#     132 )
#     134 # Supported model formats that can be loaded from and saved to
#     135 # The literals are formats with built-in support. But we also allow users to
#     136 # register their own formats. So we allow str as well.
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\onnx\checker.py:30
#      28 from google.protobuf.message import Message
# ---> 30 import onnx.defs
#      31 import onnx.onnx_cpp2py_export.checker as C  # noqa: N812
#
# ModuleNotFoundError: No module named 'onnx.defs'
#
# The above exception was the direct cause of the following exception:
#
# OnnxExporterError                         Traceback (most recent call last)
# Cell In[11], line 22
#       8 show_graph_loss(
#       9     plot_label="Convolutional SVM",
#      10     loss_history=min_loss_history,
#    (...)
#      13     filename='../docs/results/conv_svm/conv_svm_min_loss.png'
#      14 )
#      15 show_graph_loss(
#      16     plot_label="Convolutional SVM",
#      17     loss_history=max_loss_history,
#    (...)
#      20     filename='../docs/results/conv_svm/conv_svm_max_loss.png'
#      21 )
# ---> 22 show_graph_model(model=model, test_data=X_test[0], device=device, filename='models/conv_svm_visual.png')
#
# File c:\Users\larse\Documents\Projects\SpectrumSensing\src\utils.py:33, in show_graph_model(model, test_data, device, filename)
#      30 x = torch.FloatTensor(test_data).to(device).unsqueeze(0)
#      32 # Generate and save the graph
# ---> 33 torch.onnx.export(
#      34     model, x, filename + ".onnx", input_names=["input"], output_names=["output"]
#      35 )
#      37 # Convert the ONNX model to PNG
#      38 netron.start()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\torch\onnx\utils.py:551, in export(model, args, f, export_params, verbose, training, input_names, output_names, operator_export_type, opset_version, do_constant_folding, dynamic_axes, keep_initializers_as_inputs, custom_opsets, export_modules_as_functions, autograd_inlining, dynamo)
#     546 if f is None:
#     547     raise ValueError(
#     548         "Export destination must be specified for torchscript-onnx export."
#     549     )
# --> 551 _export(
#     552     model,
#     553     args,
#     554     f,
#     555     export_params,
#     556     verbose,
#     557     training,
#     558     input_names,
#     559     output_names,
#     560     operator_export_type=operator_export_type,
#     561     opset_version=opset_version,
#     562     do_constant_folding=do_constant_folding,
#     563     dynamic_axes=dynamic_axes,
#     564     keep_initializers_as_inputs=keep_initializers_as_inputs,
#     565     custom_opsets=custom_opsets,
#     566     export_modules_as_functions=export_modules_as_functions,
#     567     autograd_inlining=autograd_inlining,
#     568 )
#     570 return None
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\torch\onnx\utils.py:1722, in _export(model, args, f, export_params, verbose, training, input_names, output_names, operator_export_type, export_type, opset_version, do_constant_folding, dynamic_axes, keep_initializers_as_inputs, fixed_batch_size, custom_opsets, add_node_names, onnx_shape_inference, export_modules_as_functions, autograd_inlining)
#    1703     (
#    1704         proto,
#    1705         export_map,
#    (...)
#    1719         node_attr_to_name,
#    1720     )
#    1721 # insert function_proto into model_proto.
# -> 1722 proto = onnx_proto_utils._add_onnxscript_fn(
#    1723     proto,
#    1724     custom_opsets,
#    1725 )
#    1726 if verbose:
#    1727     torch.onnx.log("Exported graph: ", graph)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\torch\onnx\_internal\onnx_proto_utils.py:222, in _add_onnxscript_fn(model_bytes, custom_opsets)
#     220     import onnx
#     221 except ImportError as e:
# --> 222     raise errors.OnnxExporterError("Module onnx is not installed!") from e
#     224 # For > 2GB model, onnx.load_fromstring would fail. However, because
#     225 # in _export_onnx, the tensors should be saved separately if the proto
#     226 # size > 2GB, and if it for some reason did not, the model would fail on
#     227 # serialization anyway in terms of the protobuf limitation. So we don't
#     228 # need to worry about > 2GB model getting here.
#     229 model_proto = onnx.load_model_from_string(model_bytes)  # type: ignore[attr-defined]
#
# OnnxExporterError: Module onnx is not installed!

# %%
# Define parameter
import numpy as np
from scipy.signal import spectrogram
import matplotlib.pyplot as plt

def plot_spectrogram(sample, label, predicted_value):
    real_signal = sample[:, 0] # Shape: (128,1) so array of 128 real values
    imag_signal = sample[:, 1] # Shape: (128,1) so array of 128 imaginary values

    # Combine real and imaginary parts to form a complex signal 1D array
    complex_signal = real_signal + 1j * imag_signal

    # Generate spectrogram at sampling rate of 20MHz
    f, t, Sxx = spectrogram(
        x=complex_signal,
        fs=20000000,
        nperseg=32,
        noverlap=24,
        return_onesided=False
    )

    # Compensate for FFT Shift caused by GNU Radio
    Sxx = np.fft.fftshift(
        x=Sxx, 
        axes=0
    )
    f = np.fft.fftshift(f)

    # Plot spectrogram
    plt.pcolormesh(t, f, Sxx, shading='auto', vmax=np.max(Sxx)/100, cmap='coolwarm')
    plt.ylabel('Frequency [Hz]')
    plt.xlabel('Time [sec]')
    plt.colorbar(label='Power Spectral Density [dB]')
    plt.title(f'Spectrogram of {label} signal')
    plt.show()

    # Show predicted value in a bar chart
    plt.bar(np.arange(4), predicted_value)
    plt.xticks(np.arange(4), ['1', '2', '3', '4'])
    plt.ylabel('Probability')
    plt.xlabel('Signal Class')
    plt.title('Predicted Signal Class')
    plt.show()

def plot_by_idx(idx):
    # Plot the spectrogram of the first sample
    plot_spectrogram(X_test[idx], y_test[idx], results[idx]['predicted'])

plot_by_idx(8)

# %%
# Save model
torch.save(model.state_dict(), '../models/conv_svm.pth')
